# %%
import datetime
import hashlib

# %%
class Block:
    blockNo = 0
    data = None
    next = None
    hash = None
    nonce = 0
    previous_hash = 0x0
    timestamp = datetime.datetime.now()

    def __init__(self, data):
        self.data = data

    def hash(self):
        h = hashlib.sha256()
        h.update(
        str(self.nonce).encode('utf-8') +
        str(self.data).encode('utf-8') +
        str(self.previous_hash).encode('utf-8') +
        str(self.timestamp).encode('utf-8') +
        str(self.blockNo).encode('utf-8')
        )
        return h.hexdigest()

    def __str__(self):
        return "Block Hash: " + str(self.hash()) + "\nBlockNo: " + str(self.blockNo) + "\nBlock Data: " + str(self.data) + "\nHashes: " + str(self.nonce) + "\n--------------"

# %%
class Blockchain:

    diff = 20
    maxNonce = 2**32
    target = 2 ** (256-diff)

    block = Block("Genesis")
    dummy = head = block

    def add(self, block):

        block.previous_hash = self.block.hash()
        block.blockNo = self.block.blockNo + 1

        self.block.next = block
        self.block = self.block.next

    def mine(self, block):
        for n in range(self.maxNonce):
            if int(block.hash(), 16) <= self.target:
                self.add(block)
                print(block)
                break
            else:
                block.nonce += 1

blockchain = Blockchain()

for n in range(10):
    blockchain.mine(Block("Block " + str(n+1)))

while blockchain.head != None:
    print(blockchain.head)
    blockchain.head = blockchain.head.next
# Out:
# Block Hash: 9ff891b3d6089c688d17a857952512d1fb56b5fd834726ee05828f732a5437a3
# BlockNo: 1
# Block Data: Block 1
# Hashes: 969569
# --------------
# Block Hash: 1187a2eb1dd59e638c271913fb523ee6af3e1698be2a1684b5ce40d18d82e0f3
# BlockNo: 2
# Block Data: Block 2
# Hashes: 2819153
# --------------
# Block Hash: 74f92d6596d2f1743bf41c84e266875c352ab7c7c94b7704be25f7bf13dcf050
# BlockNo: 3
# Block Data: Block 3
# Hashes: 3608304
# --------------
# Block Hash: 7c4e5769a173b2183af59b278cbc12647336f46acf7032a2fde98689e1c56a2e
# BlockNo: 4
# Block Data: Block 4
# Hashes: 769487
# --------------
# Block Hash: 5b6dfae584722bdccc4044e22d61b471aaa1f715302590ee0a9c81637a997ff1
# BlockNo: 5
# Block Data: Block 5
# Hashes: 238568
# --------------
# Block Hash: cd7cde59a32b4441028a822160c9abb6da465e8c8f72d41a6b62c41227f299cf
# BlockNo: 6
# Block Data: Block 6
# Hashes: 1870680
# --------------
# Block Hash: 6e2eecadd120b6a66ea42656098939d1c803fbc0a2f6a3697510b62d53b5bd7d
# BlockNo: 7
# Block Data: Block 7
# Hashes: 641310
# --------------
# Block Hash: 7c47d0ea1dd9baad6c1e58614f12243216cd2807561f7f35a9a30623b27301ad
# BlockNo: 8
# Block Data: Block 8
# Hashes: 1619087
# --------------
# Block Hash: 1c0036ada9858f3781148cc6ff023d644821606a8d6d35801912003805f62882
# BlockNo: 9
# Block Data: Block 9
# Hashes: 286715
# --------------
# Block Hash: 746b6db9a4c2c3e1617a827b89992b7156833f7ece858b28c98bf34fcccce44f
# BlockNo: 10
# Block Data: Block 10
# Hashes: 1600991
# --------------
# Block Hash: 5d01716d14c2b938c7fe100516c6e79c1437aa862cc59fcf3b8b4269ee658e0f
# BlockNo: 0
# Block Data: Genesis
# Hashes: 0
# --------------
# Block Hash: 9ff891b3d6089c688d17a857952512d1fb56b5fd834726ee05828f732a5437a3
# BlockNo: 1
# Block Data: Block 1
# Hashes: 969569
# --------------
# Block Hash: 1187a2eb1dd59e638c271913fb523ee6af3e1698be2a1684b5ce40d18d82e0f3
# BlockNo: 2
# Block Data: Block 2
# Hashes: 2819153
# --------------
# Block Hash: 74f92d6596d2f1743bf41c84e266875c352ab7c7c94b7704be25f7bf13dcf050
# BlockNo: 3
# Block Data: Block 3
# Hashes: 3608304
# --------------
# Block Hash: 7c4e5769a173b2183af59b278cbc12647336f46acf7032a2fde98689e1c56a2e
# BlockNo: 4
# Block Data: Block 4
# Hashes: 769487
# --------------
# Block Hash: 5b6dfae584722bdccc4044e22d61b471aaa1f715302590ee0a9c81637a997ff1
# BlockNo: 5
# Block Data: Block 5
# Hashes: 238568
# --------------
# Block Hash: cd7cde59a32b4441028a822160c9abb6da465e8c8f72d41a6b62c41227f299cf
# BlockNo: 6
# Block Data: Block 6
# Hashes: 1870680
# --------------
# Block Hash: 6e2eecadd120b6a66ea42656098939d1c803fbc0a2f6a3697510b62d53b5bd7d
# BlockNo: 7
# Block Data: Block 7
# Hashes: 641310
# --------------
# Block Hash: 7c47d0ea1dd9baad6c1e58614f12243216cd2807561f7f35a9a30623b27301ad
# BlockNo: 8
# Block Data: Block 8
# Hashes: 1619087
# --------------
# Block Hash: 1c0036ada9858f3781148cc6ff023d644821606a8d6d35801912003805f62882
# BlockNo: 9
# Block Data: Block 9
# Hashes: 286715
# --------------
# Block Hash: 746b6db9a4c2c3e1617a827b89992b7156833f7ece858b28c98bf34fcccce44f
# BlockNo: 10
# Block Data: Block 10
# Hashes: 1600991
# --------------
